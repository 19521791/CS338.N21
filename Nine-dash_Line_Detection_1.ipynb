# %% [markdown]
# #Git clone YOLOv5

# %%
# !pwd
# Out:
# /home/nife/CS338/CS338.N21

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16027, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 16027 (delta 3), reused 9 (delta 1), pack-reused 16008
# Receiving objects: 100% (16027/16027), 14.62 MiB | 3.00 MiB/s, done.
# Resolving deltas: 100% (11011/11011), done.

# %% [markdown]
# #Install dependencies

# %%
# !pip install -r yolov5/requirements.txt

# %%
# !pip install roboflow

# %% [markdown]
# #Import library

# %%
import torch
from IPython.display import Image 
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

random.seed(108)

# %% [markdown]
# #Create folder held images

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="8wFIDC1vBDZcMABKQQGl")
project = rf.workspace("uit-vbp9l").project("nine-dash-line-train")
dataset = project.version(3).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to nine-dash-line-train-3 in yolov5pytorch:: 100%|██████████| 14808/14808 [00:01<00:00, 12363.53it/s]

# %%
rf = Roboflow(api_key="8wFIDC1vBDZcMABKQQGl")
project = rf.workspace("uit-vbp9l").project("nine-dash-line-amql0")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to nine-dash-line-1 in yolov5pytorch:: 100%|██████████| 1996/1996 [00:00<00:00, 11802.66it/s]

# %%
rf = Roboflow(api_key="8wFIDC1vBDZcMABKQQGl")
project = rf.workspace("uit-vbp9l").project("nine-dash-line-val")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to nine-dash-line-val-1 in yolov5pytorch:: 100%|██████████| 794/794 [00:00<00:00, 8424.94it/s]

# %%
print('torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# torch 2.0.1+cu117 _CudaDeviceProperties(name='NVIDIA GeForce RTX 3050 Ti Laptop GPU', major=8, minor=6, total_memory=3902MB, multi_processor_count=20)

# %%
cd yolov5
# Out:
# /home/nife/CS338/CS338.N21/yolov5

# %%
# !rm nine_dash_line.yaml
# !echo 'path: /home/nife/CS338/CS338.N21/' >> nine_dash_line.yaml
# !echo 'train: nine-dash-line-train-3/train/images' >> nine_dash_line.yaml
# !echo 'val: nine-dash-line-val-1/valid/images' >> nine_dash_line.yaml
# !echo 'test: nine-dash-line-1/test/images' >> nine_dash_line.yaml
# !echo 'nc: 2' >> nine_dash_line.yaml
# !echo 'names: ["noninedash","ninedash"]' >> nine_dash_line.yaml
# Out:
# rm: cannot remove 'nine_dash_line.yaml': No such file or directory

# %%
# !pwd
# Out:
# /home/nife/CS338/CS338.N21/yolov5

# %% [markdown]
# #Train

# %%
# !python train.py --img 420 --cfg yolov5s.yaml --hyp hyp.scratch-high.yaml --batch 32 --epochs 100 --data nine_dash_line.yaml --weights yolov5s.pt --workers 24 --name yolo_ninedash_det
# Out:
# train: weights=yolov5s.pt, cfg=yolov5s.yaml, data=nine_dash_line.yaml, hyp=hyp.scratch-high.yaml, epochs=100, batch_size=32, imgsz=420, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=24, project=runs/train, name=yolo_ninedash_det, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-190-gb1a1808 Python-3.9.16 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 3902MiB)
#
# ...
